# %% [markdown]
# # Plots

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
import copy
import plotly.graph_objects as go

# %%
weights = np.load('checkpoints/wine_GAP_4_weights.npy')
scale = np.load('checkpoints/wine_GAP_4_scale.npy')
n =  weights.shape[0]

# %%
sample = np.random.multivariate_normal(np.zeros(weights.shape), np.diag(scale), size=10)

# %%
sample.shape
# Out:
# (1, 3201)

# %%
fig = go.Figure(data=[go.Histogram(x=weights)])
fig.update_layout(title_text='Histogram of weights', xaxis_title_text='Weight', yaxis_title_text='Count')
fig.show()

# %%
fig = go.Figure(data=[go.Histogram(x=scale)])
fig.update_layout(title_text='Histogram of scale', xaxis_title_text='Scale', yaxis_title_text='Count')
fig.show()

# %%
weights = np.load('checkpoints/kin8nm_GAP_1_weights.npy')
scale = np.load('checkpoints/kin8nm_GAP_1_scale.npy')

# %%
fig = go.Figure(data=[go.Histogram(x=weights)])
fig.update_layout(title_text='Histogram of weights', xaxis_title_text='Weight', yaxis_title_text='Count')
fig.show()

# %%
fig = go.Figure(data=[go.Histogram(x=scale)])
fig.update_layout(title_text='Histogram of scale', xaxis_title_text='Scale', yaxis_title_text='Count')
fig.show()
